# %%
from cytoflow import *
import os

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import scipy.stats as st
from sklearn.mixture import GaussianMixture
from scipy.optimize import curve_fit
import math

mpl.rcParams['font.sans-serif'] = "Arial"
mpl.rcParams['font.family'] = "sans-serif"
plt.rcParams['figure.figsize'] = (10, 6)
mpl.rcParams['pdf.fonttype'] = 42
sns.set_style("ticks", { "xtick.major.size": 4, "ytick.major.size": 4, "font_color":'k', 'axes.edgecolor': 'k', 'xtick.color': 'k', 'ytick.color': 'k'})
sns.set_context("talk", font_scale=1.0)

# %%
plasmids = [74, 75, 76, 77, 78, 79, 
            80, 81, 82, 83, 84, 87,
            90, 91, 92, 93, 94, 96,
            97, 98, 99, 126, 217, 144]

# %%
plasmid_dict = { # maps plasmid number => plasmid name
#     57 : "ZIK1 KRAB + ZNF10 KRAB",    58 : "ZIK1 KRAB + FOXO3 TAD",
    59 : "ZIK1 KRAB + Rand Ctrl 89",  #60 : "KMT2C Dual + ZNF10 KRAB",
    61 : "KMT2C Dual + FOXO3 TAD",    #62 : "KMT2C Dual + Rand Ctrl 89",
    63 : "KMT2D Dual + ZNF10 KRAB",   #64 : "KMT2D Dual + FOXO3 TAD",
    65 : "KMT2D Dual + Rand Ctrl 89", 66 : "NCOA1 Dual + ZNF10 KRAB",
    67 : "NCOA1 Dual + FOXO3 TAD",    68 : "NCOA1 Dual + Rand Ctrl 89",
    69 : "NCOA2 Rep + FOXO3 TAD",     #70 : "Rand Ctrl + NCOA2 Act",
    #71 : "NCOA2 Rep + NCOA2 Act",     
    72 : "Rand Ctrl + Rand Ctrl 89",
    
    74 : "DMD - DMD",     75 : "DMD - RANDCTRL",      76 : "ZNF10 - ANM2",
    77 : "ZNF10 - CBX1",  78 : "RANDCTRL - RANDCTRL", 79 : "ANM2 - KIBRA",
    80 : "BIN1 - FOXO3",  81 : "CACO1 - ANM2",        82 : "CREM - MPP8",
    83 : "DPF1 - HSF2",   84 : "DPY30 - HXA13",       #85 : "FOXO3 - ZNF10",
    #86 : "IKKA - ANM2",   
    87 : "MPP8 - ZNF791", #88 : "MYBA - FOXO3",
    #89 : "NCOA2 - HXA13", 
    90 : "NOTC2 - ANM2",        91 : "NOTC2 - KIBRA",
    92 : "SMCA2 - U2AF4", 93 : "SUMO3 - SSX2",        94 : "YAF2 - ZNF791",
    #95 : "HES2 - NCOA2",  
    96 : "ATRX - HERC2",        97 : "SCML2 - NOTC2",
    98 : "CHD4 - CDYL2",  99 : "SMN2 - FOXO3",       
    
    126 : "rTetR only",  217 : "KRAB only",          144 : "MYBA only"
}

# %%
df = pd.read_csv('./data/all_cells_live_mch_gated.csv')
df = df[(df['P1'])&(df['mCherry'])]
df
# Out:
#          FSC 488/10-A  SSC 488/10-A  day               description     dox  \
# 0        8.317540e+08   219492864.0  0.0  ZIK1 KRAB + Rand Ctrl 89     0.0
# 1        4.958666e+08   180896512.0  0.0  ZIK1 KRAB + Rand Ctrl 89     0.0
# 3        1.038254e+09   372244224.0  0.0  ZIK1 KRAB + Rand Ctrl 89     0.0
# 4        8.091105e+08   349765120.0  0.0  ZIK1 KRAB + Rand Ctrl 89     0.0
# 5        5.831183e+08   284132096.0  0.0  ZIK1 KRAB + Rand Ctrl 89     0.0
# ...               ...           ...  ...                       ...     ...
# 5803242  8.637215e+08   205095936.0  5.0                  MYB only  1000.0
# 5803243  9.044457e+08   298402560.0  5.0                  MYB only  1000.0
# 5803245  9.663265e+08   209395712.0  5.0                  MYB only  1000.0
# 5803246  5.636933e+08   185259520.0  5.0                  MYB only  1000.0
# 5803248  8.897946e+08   282132736.0  5.0                  MYB only  1000.0
#
#             mCherry-A   mCitrine-A  plasmid  replicate treatment    P1  \
# 0        1.438797e+07   85923072.0       59        1.0      none  True
# 1        1.047672e+08   66599936.0       59        1.0      none  True
# 3        3.654259e+08  376630272.0       59        1.0      none  True
# 4        1.807135e+08    1863680.0       59        1.0      none  True
# 5        8.780590e+08  183085824.0       59        1.0      none  True
# ...               ...          ...      ...        ...       ...   ...
# 5803242  2.147483e+09    4770816.0      144        2.0      none  True
# 5803243  3.455867e+08  230042112.0      144        2.0      none  True
# 5803245  4.253038e+08   17569536.0      144        2.0      none  True
# 5803246  1.603625e+08  231691776.0      144        2.0      none  True
# 5803248  4.756861e+08  414080768.0      144        2.0      none  True
#
#          mCherry
# 0           True
# 1           True
# 3           True
# 4           True
# 5           True
# ...          ...
# 5803242     True
# 5803243     True
# 5803245     True
# 5803246     True
# 5803248     True
#
# [5064356 rows x 12 columns]

# %%
counts = df.groupby(['plasmid', 'description', 'replicate', 'day', 'dox', 'treatment']).count().reset_index()
counts[counts['P1'] < 100]

print(df.shape)

# drop plasmid 67 as a result 
df = df[df['plasmid'] != 67]
# drop plasmid 90, d1, r1
df = df[(df['plasmid']!=90)|(df['day']!=1)|(df['replicate']!=1)]

print(df.shape)
# Out:
# (5064356, 12)
# (5062382, 12)

# %%
def get_citrine_threshold(day):
    # return mean + 2 SDs of pJT126
    data = df[df['day']==day]
    data = data[data['plasmid']==126]
    data = data[data['treatment']=='none']
    data = data[data['dox']==0]
    logd = np.log10(list(data['mCitrine-A'])) # get log data
    
    gm = GaussianMixture(n_components = 2).fit(logd.reshape(-1,1))
    
    m0 = gm.means_[0][0]
    m1 = gm.means_[1][0]
    
    c0 = gm.covariances_[0][0]
    c1 = gm.covariances_[1][0]
    mean = m0 if m0 >= m1 else m1
    cov  = c0 if m0 >= m1 else c1
    return np.power(10, mean - 6*cov)

# %%
# %%time

day_thresh_dict = {d : get_citrine_threshold(d)[0] for d in [0, 1, 2, 3, 4, 5]}

days = list(df['day'])
cits = list(df['mCitrine-A'])
ons = [c >= day_thresh_dict[d] for c, d in zip(cits, days)]
df['Citrine On'] = ons
df
# Out:
# CPU times: user 10.6 s, sys: 762 ms, total: 11.4 s
# Wall time: 3.44 s
#          FSC 488/10-A  SSC 488/10-A  day               description     dox  \
# 0        8.317540e+08   219492864.0  0.0  ZIK1 KRAB + Rand Ctrl 89     0.0
# 1        4.958666e+08   180896512.0  0.0  ZIK1 KRAB + Rand Ctrl 89     0.0
# 3        1.038254e+09   372244224.0  0.0  ZIK1 KRAB + Rand Ctrl 89     0.0
# 4        8.091105e+08   349765120.0  0.0  ZIK1 KRAB + Rand Ctrl 89     0.0
# 5        5.831183e+08   284132096.0  0.0  ZIK1 KRAB + Rand Ctrl 89     0.0
# ...               ...           ...  ...                       ...     ...
# 5803242  8.637215e+08   205095936.0  5.0                  MYB only  1000.0
# 5803243  9.044457e+08   298402560.0  5.0                  MYB only  1000.0
# 5803245  9.663265e+08   209395712.0  5.0                  MYB only  1000.0
# 5803246  5.636933e+08   185259520.0  5.0                  MYB only  1000.0
# 5803248  8.897946e+08   282132736.0  5.0                  MYB only  1000.0
#
#             mCherry-A   mCitrine-A  plasmid  replicate treatment    P1  \
# 0        1.438797e+07   85923072.0       59        1.0      none  True
# 1        1.047672e+08   66599936.0       59        1.0      none  True
# 3        3.654259e+08  376630272.0       59        1.0      none  True
# 4        1.807135e+08    1863680.0       59        1.0      none  True
# 5        8.780590e+08  183085824.0       59        1.0      none  True
# ...               ...          ...      ...        ...       ...   ...
# 5803242  2.147483e+09    4770816.0      144        2.0      none  True
# 5803243  3.455867e+08  230042112.0      144        2.0      none  True
# 5803245  4.253038e+08   17569536.0      144        2.0      none  True
# 5803246  1.603625e+08  231691776.0      144        2.0      none  True
# 5803248  4.756861e+08  414080768.0      144        2.0      none  True
#
#          mCherry  Citrine On
# 0           True        True
# 1           True        True
# 3           True        True
# 4           True       False
# 5           True        True
# ...          ...         ...
# 5803242     True       False
# 5803243     True        True
# 5803245     True       False
# 5803246     True        True
# 5803248     True        True
#
# [5062382 rows x 13 columns]

# %% [markdown]
# # Compute normalized citrine Offs

# %%
gdf = df.groupby(['plasmid', 'description', 'day', 'dox', 'treatment', 'replicate']).mean()
gdf = gdf.reset_index()
gdf = gdf[['plasmid', 'description', 'day', 'dox', 'treatment', 'replicate', 'Citrine On']]
gdf
# Out:
#      plasmid               description  day     dox treatment  replicate  \
# 0         59  ZIK1 KRAB + Rand Ctrl 89  0.0     0.0      none        1.0
# 1         59  ZIK1 KRAB + Rand Ctrl 89  0.0     0.0      none        2.0
# 2         59  ZIK1 KRAB + Rand Ctrl 89  0.0  1000.0      none        1.0
# 3         59  ZIK1 KRAB + Rand Ctrl 89  0.0  1000.0      none        2.0
# 4         59  ZIK1 KRAB + Rand Ctrl 89  1.0     0.0      none        1.0
# ..       ...                       ...  ...     ...       ...        ...
# 928      217                 KRAB only  5.0  1000.0    9-c-RA        2.0
# 929      217                 KRAB only  5.0  1000.0      DMSO        1.0
# 930      217                 KRAB only  5.0  1000.0      DMSO        2.0
# 931      217                 KRAB only  5.0  1000.0      none        1.0
# 932      217                 KRAB only  5.0  1000.0      none        2.0
#
#      Citrine On
# 0      0.861793
# 1      0.881144
# 2      0.861793
# 3      0.881144
# 4      0.824361
# ..          ...
# 928    0.002333
# 929    0.004253
# 930    0.000802
# 931    0.003821
# 932    0.001289
#
# [933 rows x 7 columns]

# %%
pdf = gdf.pivot(
    index = ['plasmid', 'description', 'day', 'treatment', 'replicate'],
    columns = 'dox',
    values = 'Citrine On'
).reset_index()
pdf['0 dox'] = pdf[0]
pdf['1000 dox'] = pdf[1000]
pdf = pdf[['plasmid', 'description', 'day', 'treatment', 'replicate', '0 dox', '1000 dox']]
pdf['norm cit off'] = ((1-pdf['1000 dox']) - (1-pdf['0 dox']))/(pdf['0 dox'])
pdf
# Out:
# dox  plasmid               description  day treatment  replicate     0 dox  \
# 0         59  ZIK1 KRAB + Rand Ctrl 89  0.0      none        1.0  0.861793
# 1         59  ZIK1 KRAB + Rand Ctrl 89  0.0      none        2.0  0.881144
# 2         59  ZIK1 KRAB + Rand Ctrl 89  1.0      none        1.0  0.824361
# 3         59  ZIK1 KRAB + Rand Ctrl 89  1.0      none        2.0  0.836066
# 4         59  ZIK1 KRAB + Rand Ctrl 89  2.0      none        1.0  0.804082
# ..       ...                       ...  ...       ...        ...       ...
# 462      217                 KRAB only  5.0    9-c-RA        2.0  0.009097
# 463      217                 KRAB only  5.0      DMSO        1.0  0.012594
# 464      217                 KRAB only  5.0      DMSO        2.0  0.011506
# 465      217                 KRAB only  5.0      none        1.0  0.794225
# 466      217                 KRAB only  5.0      none        2.0  0.764386
#
# dox  1000 dox  norm cit off
# 0    0.861793      0.000000
# 1    0.881144      0.000000
# 2    0.642094      0.221101
# 3    0.636364      0.238859
# 4    0.009737      0.987891
# ..        ...           ...
# 462  0.002333      0.743539
# 463  0.004253      0.662333
# 464  0.000802      0.930258
# 465  0.003821      0.995189
# 466  0.001289      0.998313
#
# [467 rows x 8 columns]

# %%
fig, ax = plt.subplots(figsize=(5, 3))

plasmid = 76

def make_lineplot(ax, plasmid):
    xdf = pdf[pdf['plasmid'].isin([plasmid, 126])]
    xdf = xdf[xdf['treatment']=='none']

    ax.axhline(y = 0, color = '#444444', linestyle = '--', zorder = 0)

    pal = ["#23bedb", "#DEDEDE"] if plasmid != 126 else ["#DEDEDE"]
    if plasmid >= 126:
        pal = pal[::-1]
    
    sns.scatterplot(
        data = xdf,
        x = 'day',
        y = 'norm cit off',
        hue = 'description',
        palette = pal,
        legend = False,
        ax = ax
    )
#     sns.lineplot(
#         data = xdf,
#         ci = None,
#         x = 'day',
#         y = 'norm cit off',
#         hue = 'plasmid',
#         palette = pal,
#         legend = False,
#         ax = ax
#     )
    
    def sil_curve(t, kS, tLag1):
        return 0.0*(t<tLag1) + (1-np.exp(-1*kS*(t-tLag1)))*(t>=tLag1)
        
    xvalues = list(xdf[xdf['plasmid']==plasmid].dropna(subset=['norm cit off'])['day'])
    yvalues = list(xdf[xdf['plasmid']==plasmid].dropna(subset=['norm cit off'])['norm cit off'])
    popt, pcov = curve_fit(sil_curve, xvalues, yvalues)
    fit_x = list(np.linspace(0.01, 5))
    fit_y = sil_curve(fit_x, *popt) 
    ax.plot(fit_x, fit_y, color = '#23bedb')

    ax.set_xlim(-0.1, 5.1)
    ax.set_xticks([0, 1, 2, 3, 4, 5])
    ax.set_ylim(-0.05, 1.05)
    ax.set_yticks([0, 0.5, 1])
    
    ax.set_title(plasmid_dict[plasmid])
    
    ax.set_xlabel('Day')
    ax.set_ylabel('Norm. Fraction Off')
    #ax.legend(title='', markerscale=1.0)
    
    sns.despine(ax=ax)
    
    return popt
    
make_lineplot(ax, plasmid)
# Out:
# array([3.17814054, 0.93836852])

# %% [markdown]
# # Making line plots

# %%
fig, ax = plt.subplots(6, 4, figsize=(20, 16))

plasmid_arr = [[plasmids[4*i + j] for j in range(4)] for i in range(6)]

popt_dict = { p : [] for p in plasmids }

for i in range(len(plasmid_arr)):
    for j in range(len(plasmid_arr[i])):
        popt_dict[plasmid_arr[i][j]] = make_lineplot(ax[i][j], plasmid_arr[i][j])

plt.tight_layout()

fig.savefig('./repressors_d5_omnibus.png', dpi = 300)
fig.savefig('./repressors_d5_omnibus.pdf', bbox_inches = 'tight')

# %%
for plasmid in plasmids:
    fig, ax = plt.subplots(figsize=(4, 2))
    
    descr = plasmid_dict[plasmid]
    popt = make_lineplot(ax, plasmid)
    
    fig.savefig('./lineplots/' + descr + ' Silencing.pdf', bbox_inches = 'tight')
    print(descr)
    plt.close(fig)
# Out:
# DMD - DMD
# DMD - RANDCTRL
# ZNF10 - ANM2
# ZNF10 - CBX1
# RANDCTRL - RANDCTRL
# ANM2 - KIBRA
# BIN1 - FOXO3
# CACO1 - ANM2
# CREM - MPP8
# DPF1 - HSF2
# DPY30 - HXA13
# MPP8 - ZNF791
# NOTC2 - ANM2
# NOTC2 - KIBRA
# SMCA2 - U2AF4
# SUMO3 - SSX2
# YAF2 - ZNF791
# ATRX - HERC2
# SCML2 - NOTC2
# CHD4 - CDYL2
# SMN2 - FOXO3
# rTetR only
# KRAB only
# MYBA only

# %% [markdown]
# # Correlation with screen data

# %%
qdf = pd.DataFrame.from_dict({
    'plasmid' : plasmids,
    'description' : [plasmid_dict[p] for p in plasmids],
    'ks' : [popt_dict[p][0] for p in plasmids],
    'tlag' : [popt_dict[p][1] for p in plasmids]
})

qdf = qdf[qdf['plasmid'] < 126]

# %%
screen_data = pd.read_csv('../../Analysis/20211021b_synergy_with_medians/pairs_baseline_sums_computed.csv')
screen_data
# Out:
#                                                    pair            type  \
# 0     Short_nuclear_domain;NCOA2_HUMAN;Nuc_rec_co-ac...  0 control Pair
# 1     Silencer_tiles;ENSG00000179833;22 --- Silencer...  0 control Pair
# 2     Silencer_tiles;ENSG00000069812;10 --- Silencer...  0 control Pair
# 3     Short_nuclear_domain;ZN473_HUMAN;KRAB;1;41 ---...  0 control Pair
# 4     Short_nuclear_domain;HERC2_HUMAN;Cyt-b5;1207;7...  0 control Pair
# ...                                                 ...             ...
# 8518  Random_control;;;21; --- Silencer_tiles;ENSG00...  1 control Pair
# 8519  DMD_control_tiles;ENSG00000198947;;255; --- Sh...  1 control Pair
# 8520  Random_control;;;21; --- Short_nuclear_domain;...  1 control Pair
# 8521  DMD_control_tiles;ENSG00000198947;;255; --- Sh...  1 control Pair
# 8522  Random_control;;;21; --- Short_nuclear_domain;...  1 control Pair
#
#       enrichment_ratio_r1_d2  enrichment_ratio_r1_d5  enrichment_ratio_r1_d10  \
# 0                   3.352891                0.370286                 0.174506
# 1                   2.398298               -0.753393                 4.163810
# 2                  -3.062010               -2.319193                 3.172887
# 3                   2.134786               -0.638436                 4.103685
# 4                  -1.570582               -1.178792                 0.423771
# ...                      ...                     ...                      ...
# 8518                     NaN                     NaN                -2.269101
# 8519                     NaN                     NaN                -3.658668
# 8520                     NaN                     NaN                      NaN
# 8521                     NaN                     NaN                      NaN
# 8522                     NaN                     NaN                      NaN
#
#       enrichment_ratio_r2_d2  enrichment_ratio_r2_d5  enrichment_ratio_r2_d10  \
# 0                   3.710054                0.008381                 0.250713
# 1                   3.465392               -0.849573                 0.097015
# 2                  -2.066907               -1.601928                 0.462344
# 3                   3.051059               -0.636362                 0.239978
# 4                  -1.388748               -2.523017                -0.896399
# ...                      ...                     ...                      ...
# 8518                     NaN                     NaN                      NaN
# 8519                     NaN                     NaN                -0.719826
# 8520                     NaN                     NaN                -0.705641
# 8521                     NaN                     NaN                 2.168829
# 8522                     NaN                     NaN                -3.979563
#
#       enrichment_fraction_r1_d2  enrichment_fraction_r1_d5  ...  act_hit  \
# 0                      0.910849                   0.563816  ...     True
# 1                      0.840556                   0.372335  ...     True
# 2                      0.106936                   0.166930  ...    False
# 3                      0.814530                   0.391138  ...     True
# 4                      0.251874                   0.306385  ...      NaN
# ...                         ...                        ...  ...      ...
# 8518                        NaN                        NaN  ...      NaN
# 8519                        NaN                        NaN  ...      NaN
# 8520                        NaN                        NaN  ...      NaN
# 8521                        NaN                        NaN  ...      NaN
# 8522                        NaN                        NaN  ...      NaN
#
#       rep_hit  d1_prior_avg_d5  d1_prior_avg_dm  d1_prior_avg_d2  \
# 0       False         0.073816         0.216122        -7.111908
# 1        True              NaN              NaN              NaN
# 2        True              NaN              NaN              NaN
# 3        True         0.178962        -0.339994        -8.623200
# 4        True         5.129901         1.486742         4.050937
# ...       ...              ...              ...              ...
# 8518      NaN        -0.386730        -0.391739         1.123830
# 8519      NaN        -0.446548        -0.480109         0.872274
# 8520      NaN        -0.386730        -0.391739         1.123830
# 8521      NaN        -0.446548        -0.480109         0.872274
# 8522      NaN        -0.386730        -0.391739         1.123830
#
#       d2_prior_avg_d5  d2_prior_avg_dm  d2_prior_avg_d2  baseline_sum_d2  \
# 0                 NaN              NaN              NaN         1.293060
# 1                 NaN              NaN              NaN         5.224450
# 2                 NaN              NaN              NaN        -3.550428
# 3            0.178962        -0.339994        -8.623200         4.937157
# 4                 NaN              NaN              NaN        -3.145337
# ...               ...              ...              ...              ...
# 8518              NaN              NaN              NaN        -3.344489
# 8519         6.952695         6.040754         6.560139        -3.695210
# 8520         6.952695         6.040754         6.560139        -3.958551
# 8521        -1.278913        -0.444267        -5.456627        -2.312788
# 8522         0.178962        -0.339994        -8.623200         1.018929
#
#       baseline_sum_d5
# 0            2.454786
# 1            0.720589
# 2           -1.531781
# 3            1.679141
# 4           -0.413865
# ...               ...
# 8518        -2.069157
# 8519        -1.679489
# 8520        -2.533714
# 8521         3.085142
# 8522         0.787207
#
# [8523 rows x 69 columns]

# %%
descrs = list(qdf['description'])
splits = [d.split(' ') for d in descrs]
d1s = [s[0] for s in splits]
d2s = [s[2] for s in splits]

qdf['domain1'] = d1s
qdf['domain2'] = d2s

qdf
# Out:
#     plasmid          description        ks      tlag   domain1   domain2
# 0        74            DMD - DMD  0.015397  0.534274       DMD       DMD
# 1        75       DMD - RANDCTRL  0.025531  1.804237       DMD  RANDCTRL
# 2        76         ZNF10 - ANM2  3.178141  0.938369     ZNF10      ANM2
# 3        77         ZNF10 - CBX1  2.958838  0.926416     ZNF10      CBX1
# 4        78  RANDCTRL - RANDCTRL  0.075772  1.292963  RANDCTRL  RANDCTRL
# 5        79         ANM2 - KIBRA  0.026166  0.669465      ANM2     KIBRA
# 6        80         BIN1 - FOXO3  1.252993  0.913119      BIN1     FOXO3
# 7        81         CACO1 - ANM2  0.016826  1.399375     CACO1      ANM2
# 8        82          CREM - MPP8  3.088495  0.950128      CREM      MPP8
# 9        83          DPF1 - HSF2  1.481086  0.922303      DPF1      HSF2
# 10       84        DPY30 - HXA13  0.538830  0.579243     DPY30     HXA13
# 11       87        MPP8 - ZNF791  3.403814  0.934646      MPP8    ZNF791
# 12       90         NOTC2 - ANM2  0.035155 -0.096756     NOTC2      ANM2
# 13       91        NOTC2 - KIBRA  0.771948  0.921027     NOTC2     KIBRA
# 14       92        SMCA2 - U2AF4  0.166648  0.449262     SMCA2     U2AF4
# 15       93         SUMO3 - SSX2  3.067263  0.926508     SUMO3      SSX2
# 16       94        YAF2 - ZNF791  3.973450  0.927227      YAF2    ZNF791
# 17       96         ATRX - HERC2  2.866741  0.939224      ATRX     HERC2
# 18       97        SCML2 - NOTC2  2.651466  0.967238     SCML2     NOTC2
# 19       98         CHD4 - CDYL2  4.004404  0.916355      CHD4     CDYL2
# 20       99         SMN2 - FOXO3  0.048303  0.089964      SMN2     FOXO3

# %%
screen_data_d1 = list(screen_data['d1_Gene'])
screen_data_d2 = list(screen_data['d2_Gene'])
screen_data['description'] = [s1 + ' - ' + s2 for s1, s2 in zip(screen_data_d1, screen_data_d2)]
screen_data
# Out:
#                                                    pair            type  \
# 0     Short_nuclear_domain;NCOA2_HUMAN;Nuc_rec_co-ac...  0 control Pair
# 1     Silencer_tiles;ENSG00000179833;22 --- Silencer...  0 control Pair
# 2     Silencer_tiles;ENSG00000069812;10 --- Silencer...  0 control Pair
# 3     Short_nuclear_domain;ZN473_HUMAN;KRAB;1;41 ---...  0 control Pair
# 4     Short_nuclear_domain;HERC2_HUMAN;Cyt-b5;1207;7...  0 control Pair
# ...                                                 ...             ...
# 8518  Random_control;;;21; --- Silencer_tiles;ENSG00...  1 control Pair
# 8519  DMD_control_tiles;ENSG00000198947;;255; --- Sh...  1 control Pair
# 8520  Random_control;;;21; --- Short_nuclear_domain;...  1 control Pair
# 8521  DMD_control_tiles;ENSG00000198947;;255; --- Sh...  1 control Pair
# 8522  Random_control;;;21; --- Short_nuclear_domain;...  1 control Pair
#
#       enrichment_ratio_r1_d2  enrichment_ratio_r1_d5  enrichment_ratio_r1_d10  \
# 0                   3.352891                0.370286                 0.174506
# 1                   2.398298               -0.753393                 4.163810
# 2                  -3.062010               -2.319193                 3.172887
# 3                   2.134786               -0.638436                 4.103685
# 4                  -1.570582               -1.178792                 0.423771
# ...                      ...                     ...                      ...
# 8518                     NaN                     NaN                -2.269101
# 8519                     NaN                     NaN                -3.658668
# 8520                     NaN                     NaN                      NaN
# 8521                     NaN                     NaN                      NaN
# 8522                     NaN                     NaN                      NaN
#
#       enrichment_ratio_r2_d2  enrichment_ratio_r2_d5  enrichment_ratio_r2_d10  \
# 0                   3.710054                0.008381                 0.250713
# 1                   3.465392               -0.849573                 0.097015
# 2                  -2.066907               -1.601928                 0.462344
# 3                   3.051059               -0.636362                 0.239978
# 4                  -1.388748               -2.523017                -0.896399
# ...                      ...                     ...                      ...
# 8518                     NaN                     NaN                      NaN
# 8519                     NaN                     NaN                -0.719826
# 8520                     NaN                     NaN                -0.705641
# 8521                     NaN                     NaN                 2.168829
# 8522                     NaN                     NaN                -3.979563
#
#       enrichment_fraction_r1_d2  enrichment_fraction_r1_d5  ...  rep_hit  \
# 0                      0.910849                   0.563816  ...    False
# 1                      0.840556                   0.372335  ...     True
# 2                      0.106936                   0.166930  ...     True
# 3                      0.814530                   0.391138  ...     True
# 4                      0.251874                   0.306385  ...     True
# ...                         ...                        ...  ...      ...
# 8518                        NaN                        NaN  ...      NaN
# 8519                        NaN                        NaN  ...      NaN
# 8520                        NaN                        NaN  ...      NaN
# 8521                        NaN                        NaN  ...      NaN
# 8522                        NaN                        NaN  ...      NaN
#
#       d1_prior_avg_d5  d1_prior_avg_dm  d1_prior_avg_d2  d2_prior_avg_d5  \
# 0            0.073816         0.216122        -7.111908              NaN
# 1                 NaN              NaN              NaN              NaN
# 2                 NaN              NaN              NaN              NaN
# 3            0.178962        -0.339994        -8.623200         0.178962
# 4            5.129901         1.486742         4.050937              NaN
# ...               ...              ...              ...              ...
# 8518        -0.386730        -0.391739         1.123830              NaN
# 8519        -0.446548        -0.480109         0.872274         6.952695
# 8520        -0.386730        -0.391739         1.123830         6.952695
# 8521        -0.446548        -0.480109         0.872274        -1.278913
# 8522        -0.386730        -0.391739         1.123830         0.178962
#
#       d2_prior_avg_dm  d2_prior_avg_d2  baseline_sum_d2  baseline_sum_d5  \
# 0                 NaN              NaN         1.293060         2.454786
# 1                 NaN              NaN         5.224450         0.720589
# 2                 NaN              NaN        -3.550428        -1.531781
# 3           -0.339994        -8.623200         4.937157         1.679141
# 4                 NaN              NaN        -3.145337        -0.413865
# ...               ...              ...              ...              ...
# 8518              NaN              NaN        -3.344489        -2.069157
# 8519         6.040754         6.560139        -3.695210        -1.679489
# 8520         6.040754         6.560139        -3.958551        -2.533714
# 8521        -0.444267        -5.456627        -2.312788         3.085142
# 8522        -0.339994        -8.623200         1.018929         0.787207
#
#             description
# 0          NCOA2 - TET2
# 1     SERTAD2 - SERTAD2
# 2           HES2 - HES2
# 3         ZN473 - ZN473
# 4         HERC2 - ADRM1
# ...                 ...
# 8518    RANDCTRL - CBX7
# 8519         DMD - CBX1
# 8520    RANDCTRL - CBX1
# 8521        DMD - CXXC1
# 8522   RANDCTRL - ZN473
#
# [8523 rows x 70 columns]

# %%
mdf = qdf.set_index('description').join(
    screen_data.set_index('description'),
    how = 'left',
    rsuffix = '_screen'
).reset_index()
mdf = mdf[mdf['character'] != 'Control']
mdf = mdf[mdf['description'] != 'DMD - DMD']
mdf = mdf[mdf['description'] != 'DMD - RANDCTRL']
mdf
# Out:
#        description  plasmid        ks      tlag domain1 domain2  \
# 0     ANM2 - KIBRA       79  0.026166  0.669465    ANM2   KIBRA
# 1     ATRX - HERC2       96  2.866741  0.939224    ATRX   HERC2
# 2     BIN1 - FOXO3       80  1.252993  0.913119    BIN1   FOXO3
# 3     CACO1 - ANM2       81  0.016826  1.399375   CACO1    ANM2
# 4     CHD4 - CDYL2       98  4.004404  0.916355    CHD4   CDYL2
# 5      CREM - MPP8       82  3.088495  0.950128    CREM    MPP8
# 235    DPF1 - HSF2       83  1.481086  0.922303    DPF1    HSF2
# 236  DPY30 - HXA13       84  0.538830  0.579243   DPY30   HXA13
# 237  MPP8 - ZNF791       87  3.403814  0.934646    MPP8  ZNF791
# 238   NOTC2 - ANM2       90  0.035155 -0.096756   NOTC2    ANM2
# 239  NOTC2 - KIBRA       91  0.771948  0.921027   NOTC2   KIBRA
# 339  SCML2 - NOTC2       97  2.651466  0.967238   SCML2   NOTC2
# 340  SMCA2 - U2AF4       92  0.166648  0.449262   SMCA2   U2AF4
# 341   SMN2 - FOXO3       99  0.048303  0.089964    SMN2   FOXO3
# 342   SUMO3 - SSX2       93  3.067263  0.926508   SUMO3    SSX2
# 343  YAF2 - ZNF791       94  3.973450  0.927227    YAF2  ZNF791
# 344   ZNF10 - ANM2       76  3.178141  0.938369   ZNF10    ANM2
# 345   ZNF10 - CBX1       77  2.958838  0.926416   ZNF10    CBX1
#
#                                                   pair            type  \
# 0    Short_nuclear_domain;ANM2_HUMAN;SH3_1;18;45 --...  0 control Pair
# 1    Silencer_tiles;ENSG00000085224;242 --- Short_n...  0 control Pair
# 2    Short_nuclear_domain;BIN1_HUMAN;SH3_9;513;63 -...  0 control Pair
# 3    Short_nuclear_domain;CACO1_HUMAN;Zn-C2H2_12;61...  0 control Pair
# 4    Silencer_tiles;ENSG00000111642;38 --- Short_nu...  0 control Pair
# 5    Short_nuclear_domain;CREM_HUMAN;bZIP_1;265;45 ...  0 control Pair
# 235  Short_nuclear_domain;DPF1_HUMAN;Requiem_N;34;7...  0 control Pair
# 236  Short_nuclear_domain;DPY30_HUMAN;Dpy-30;19;41 ...  0 control Pair
# 237  Short_nuclear_domain;MPP8_HUMAN;Chromo;44;50 -...  0 control Pair
# 238  Short_nuclear_domain;NOTC2_HUMAN;Notch;1440;34...  0 control Pair
# 239  Short_nuclear_domain;NOTC2_HUMAN;Notch;1440;34...  0 control Pair
# 339  Silencer_tiles;ENSG00000102098;62 --- Short_nu...  0 control Pair
# 340  Short_nuclear_domain;SMCA2_HUMAN;QLQ;150;34 --...  0 control Pair
# 341  Silencer_tiles;ENSG00000205571;13 --- Short_nu...  0 control Pair
# 342  Short_nuclear_domain;SUMO3_HUMAN;Rad60-SLD;12;...  0 control Pair
# 343  Short_nuclear_domain;YAF2_HUMAN;YAF2_RYBP;78;3...  0 control Pair
# 344  Human_KRAB_variant;P21506;146 --- Short_nuclea...  0 control Pair
# 345  Human_KRAB_variant;P21506;146 --- Short_nuclea...  0 control Pair
#
#      enrichment_ratio_r1_d2  enrichment_ratio_r1_d5  ...  act_hit  rep_hit  \
# 0                  4.399647                1.963231  ...     True    False
# 1                 -2.256287               -2.227251  ...    False     True
# 2                  2.910184               -1.215860  ...     True     True
# 3                  4.293037                1.819199  ...     True    False
# 4                 -2.505355               -3.874072  ...    False     True
# 5                 -1.771883               -3.459034  ...    False     True
# 235               -6.270534                1.298109  ...    False    False
# 236                     NaN                     NaN  ...      NaN      NaN
# 237               -5.163618               -3.176634  ...      NaN     True
# 238                4.293155                1.939422  ...     True    False
# 239                1.132315               -1.144821  ...     True     True
# 339               -1.609766               -1.261095  ...    False     True
# 340                3.262467                0.838505  ...     True    False
# 341                4.688901                2.549140  ...     True    False
# 342               -2.600175               -3.377838  ...    False     True
# 343               -3.129806               -4.101878  ...    False     True
# 344               -3.077474               -4.039409  ...    False     True
# 345               -2.280802                0.236960  ...    False     True
#
#      d1_prior_avg_d5  d1_prior_avg_dm  d1_prior_avg_d2  d2_prior_avg_d5  \
# 0          -1.019050        -0.726941        -5.645672         0.243639
# 1                NaN              NaN              NaN         5.129901
# 2           2.683747         1.246747         1.224325         1.492156
# 3           0.142909        -0.196617        -4.683274        -1.019050
# 4           4.154102         1.279604              NaN         5.177775
# 5           4.587577         1.876879         2.598693         6.513346
# 235        -0.877510        -1.191838        -2.743392         4.314440
# 236        -0.750871        -0.694016        -3.696281         3.056264
# 237         6.513346         4.151363         5.335222              NaN
# 238         0.759808         0.077752        -5.258400        -1.019050
# 239         0.759808         0.077752        -5.258400         0.243639
# 339         4.346822         0.995849              NaN         0.759808
# 340         1.088938         0.870292        -6.791645        -0.053175
# 341              NaN              NaN              NaN         1.492156
# 342         6.764935         4.418768         2.783581         3.380894
# 343         6.257689         3.329343         1.811529              NaN
# 344              NaN              NaN              NaN        -1.019050
# 345              NaN              NaN              NaN         6.952695
#
#      d2_prior_avg_dm  d2_prior_avg_d2  baseline_sum_d2  baseline_sum_d5
# 0           0.312334        -6.707792        -0.145996         3.174879
# 1           1.486742         4.050937        -3.686474        -0.230680
# 2           1.681687        -8.389172         1.352338         1.236541
# 3          -0.726941        -5.645672        -1.545303         3.142817
# 4           4.974258         3.329373        -4.176443        -4.738963
# 5           4.151363         5.335222        -4.841218        -2.697996
# 235         1.798662              NaN        -3.831008         0.835209
# 236         2.096968        -0.043040        -3.131331         2.734139
# 237              NaN              NaN        -5.252263        -4.962111
# 238        -0.726941        -5.645672        -0.914634         2.972803
# 239         0.312334        -6.707792        -0.210166         2.556613
# 339         0.077752        -5.258400        -2.497523         0.118596
# 340         0.131211        -3.355393        -1.729842         1.872948
# 341         1.681687        -8.389172         1.642877         2.434642
# 342         3.499111         4.168672        -3.906820        -3.656192
# 343              NaN              NaN        -4.613514        -5.325869
# 344        -0.726941        -5.645672        -2.992981        -1.179180
# 345         6.040754         6.560139        -5.076650        -5.456065
#
# [18 rows x 75 columns]

# %%
# manually add back the controls

cdf = qdf[qdf['description'].isin(['DMD - DMD', 'DMD - RANDCTRL', 'RANDCTRL - RANDCTRL'])]
cdf
# Out:
#    plasmid          description        ks      tlag   domain1   domain2
# 0       74            DMD - DMD  0.015397  0.534274       DMD       DMD
# 1       75       DMD - RANDCTRL  0.025531  1.804237       DMD  RANDCTRL
# 4       78  RANDCTRL - RANDCTRL  0.075772  1.292963  RANDCTRL  RANDCTRL

# %%
cdict = {
    "DMD - DMD" : "DMD_control_tiles;ENSG00000198947;;131; -  DMD_control_tiles;ENSG00000198947;;297;",
    "DMD - RANDCTRL" : "DMD_control_tiles;ENSG00000198947;;297; - Random_control;;;21;",
    "RANDCTRL - RANDCTRL" : "Random_control;;;205; - Random_control;;;410;"
}

cdf['description+'] = [cdict[d] for d in list(cdf['description'])]
cdf
# Out:
# /var/folders/dc/w29p98q54dv6v4wg20gnvzg40000gn/T/ipykernel_95466/681205518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    plasmid          description        ks      tlag   domain1   domain2  \
# 0       74            DMD - DMD  0.015397  0.534274       DMD       DMD
# 1       75       DMD - RANDCTRL  0.025531  1.804237       DMD  RANDCTRL
# 4       78  RANDCTRL - RANDCTRL  0.075772  1.292963  RANDCTRL  RANDCTRL
#
#                                         description+
# 0  DMD_control_tiles;ENSG00000198947;;131; -  DMD...
# 1  DMD_control_tiles;ENSG00000198947;;297; - Rand...
# 4      Random_control;;;205; - Random_control;;;410;

# %%
screen_data_d1 = list(screen_data['domain1'])
screen_data_d2 = list(screen_data['domain2'])
screen_data['description+'] = [s1 + ' - ' + s2 for s1, s2 in zip(screen_data_d1, screen_data_d2)]
screen_data
# Out:
#                                                    pair            type  \
# 0     Short_nuclear_domain;NCOA2_HUMAN;Nuc_rec_co-ac...  0 control Pair
# 1     Silencer_tiles;ENSG00000179833;22 --- Silencer...  0 control Pair
# 2     Silencer_tiles;ENSG00000069812;10 --- Silencer...  0 control Pair
# 3     Short_nuclear_domain;ZN473_HUMAN;KRAB;1;41 ---...  0 control Pair
# 4     Short_nuclear_domain;HERC2_HUMAN;Cyt-b5;1207;7...  0 control Pair
# ...                                                 ...             ...
# 8518  Random_control;;;21; --- Silencer_tiles;ENSG00...  1 control Pair
# 8519  DMD_control_tiles;ENSG00000198947;;255; --- Sh...  1 control Pair
# 8520  Random_control;;;21; --- Short_nuclear_domain;...  1 control Pair
# 8521  DMD_control_tiles;ENSG00000198947;;255; --- Sh...  1 control Pair
# 8522  Random_control;;;21; --- Short_nuclear_domain;...  1 control Pair
#
#       enrichment_ratio_r1_d2  enrichment_ratio_r1_d5  enrichment_ratio_r1_d10  \
# 0                   3.352891                0.370286                 0.174506
# 1                   2.398298               -0.753393                 4.163810
# 2                  -3.062010               -2.319193                 3.172887
# 3                   2.134786               -0.638436                 4.103685
# 4                  -1.570582               -1.178792                 0.423771
# ...                      ...                     ...                      ...
# 8518                     NaN                     NaN                -2.269101
# 8519                     NaN                     NaN                -3.658668
# 8520                     NaN                     NaN                      NaN
# 8521                     NaN                     NaN                      NaN
# 8522                     NaN                     NaN                      NaN
#
#       enrichment_ratio_r2_d2  enrichment_ratio_r2_d5  enrichment_ratio_r2_d10  \
# 0                   3.710054                0.008381                 0.250713
# 1                   3.465392               -0.849573                 0.097015
# 2                  -2.066907               -1.601928                 0.462344
# 3                   3.051059               -0.636362                 0.239978
# 4                  -1.388748               -2.523017                -0.896399
# ...                      ...                     ...                      ...
# 8518                     NaN                     NaN                      NaN
# 8519                     NaN                     NaN                -0.719826
# 8520                     NaN                     NaN                -0.705641
# 8521                     NaN                     NaN                 2.168829
# 8522                     NaN                     NaN                -3.979563
#
#       enrichment_fraction_r1_d2  enrichment_fraction_r1_d5  ...  \
# 0                      0.910849                   0.563816  ...
# 1                      0.840556                   0.372335  ...
# 2                      0.106936                   0.166930  ...
# 3                      0.814530                   0.391138  ...
# 4                      0.251874                   0.306385  ...
# ...                         ...                        ...  ...
# 8518                        NaN                        NaN  ...
# 8519                        NaN                        NaN  ...
# 8520                        NaN                        NaN  ...
# 8521                        NaN                        NaN  ...
# 8522                        NaN                        NaN  ...
#
#       d1_prior_avg_d5  d1_prior_avg_dm  d1_prior_avg_d2  d2_prior_avg_d5  \
# 0            0.073816         0.216122        -7.111908              NaN
# 1                 NaN              NaN              NaN              NaN
# 2                 NaN              NaN              NaN              NaN
# 3            0.178962        -0.339994        -8.623200         0.178962
# 4            5.129901         1.486742         4.050937              NaN
# ...               ...              ...              ...              ...
# 8518        -0.386730        -0.391739         1.123830              NaN
# 8519        -0.446548        -0.480109         0.872274         6.952695
# 8520        -0.386730        -0.391739         1.123830         6.952695
# 8521        -0.446548        -0.480109         0.872274        -1.278913
# 8522        -0.386730        -0.391739         1.123830         0.178962
#
#       d2_prior_avg_dm  d2_prior_avg_d2  baseline_sum_d2  baseline_sum_d5  \
# 0                 NaN              NaN         1.293060         2.454786
# 1                 NaN              NaN         5.224450         0.720589
# 2                 NaN              NaN        -3.550428        -1.531781
# 3           -0.339994        -8.623200         4.937157         1.679141
# 4                 NaN              NaN        -3.145337        -0.413865
# ...               ...              ...              ...              ...
# 8518              NaN              NaN        -3.344489        -2.069157
# 8519         6.040754         6.560139        -3.695210        -1.679489
# 8520         6.040754         6.560139        -3.958551        -2.533714
# 8521        -0.444267        -5.456627        -2.312788         3.085142
# 8522        -0.339994        -8.623200         1.018929         0.787207
#
#             description                                       description+
# 0          NCOA2 - TET2  Short_nuclear_domain;NCOA2_HUMAN;Nuc_rec_co-ac...
# 1     SERTAD2 - SERTAD2  Silencer_tiles;ENSG00000179833;22 - Silencer_t...
# 2           HES2 - HES2  Silencer_tiles;ENSG00000069812;10 - Silencer_t...
# 3         ZN473 - ZN473  Short_nuclear_domain;ZN473_HUMAN;KRAB;1;41 - S...
# 4         HERC2 - ADRM1  Short_nuclear_domain;HERC2_HUMAN;Cyt-b5;1207;7...
# ...                 ...                                                ...
# 8518    RANDCTRL - CBX7  Random_control;;;21; - Silencer_tiles;ENSG0000...
# 8519         DMD - CBX1  DMD_control_tiles;ENSG00000198947;;255; - Shor...
# 8520    RANDCTRL - CBX1  Random_control;;;21; - Short_nuclear_domain;CB...
# 8521        DMD - CXXC1  DMD_control_tiles;ENSG00000198947;;255; - Shor...
# 8522   RANDCTRL - ZN473  Random_control;;;21; - Short_nuclear_domain;ZN...
#
# [8523 rows x 71 columns]

# %%
ccdf = cdf.set_index('description+').join(
    screen_data.set_index('description+'),
    how = 'left',
    rsuffix = '_screen'
).reset_index()
ccdf = ccdf.drop(['description+'], axis=1)
ccdf
# Out:
#    plasmid          description        ks      tlag   domain1   domain2  \
# 0       74            DMD - DMD  0.015397  0.534274       DMD       DMD
# 1       75       DMD - RANDCTRL  0.025531  1.804237       DMD  RANDCTRL
# 2       78  RANDCTRL - RANDCTRL  0.075772  1.292963  RANDCTRL  RANDCTRL
#
#                                                 pair            type  \
# 0                                                NaN             NaN
# 1  DMD_control_tiles;ENSG00000198947;;297; --- Ra...  2 control Pair
# 2    Random_control;;;205; --- Random_control;;;410;  2 control Pair
#
#    enrichment_ratio_r1_d2  enrichment_ratio_r1_d5  ...  rep_hit  \
# 0                     NaN                     NaN  ...      NaN
# 1               -1.674298                1.845453  ...    False
# 2               -1.136912                1.514022  ...    False
#
#    d1_prior_avg_d5  d1_prior_avg_dm  d1_prior_avg_d2  d2_prior_avg_d5  \
# 0              NaN              NaN              NaN              NaN
# 1        -0.481389        -0.300723         0.880544        -0.386730
# 2        -0.213846        -0.499577         0.965604        -0.705059
#
#    d2_prior_avg_dm  d2_prior_avg_d2  baseline_sum_d2  baseline_sum_d5  \
# 0              NaN              NaN              NaN              NaN
# 1        -0.391739         1.123830        -2.633567         1.421112
# 2        -0.498968         0.924894        -2.878058         0.765639
#
#     description_screen
# 0                  NaN
# 1       DMD - RANDCTRL
# 2  RANDCTRL - RANDCTRL
#
# [3 rows x 76 columns]

# %%
zdf = pd.concat([mdf, ccdf])
zdf.sort_values(by='plasmid')
# Out:
#              description  plasmid        ks      tlag   domain1   domain2  \
# 0              DMD - DMD       74  0.015397  0.534274       DMD       DMD
# 1         DMD - RANDCTRL       75  0.025531  1.804237       DMD  RANDCTRL
# 344         ZNF10 - ANM2       76  3.178141  0.938369     ZNF10      ANM2
# 345         ZNF10 - CBX1       77  2.958838  0.926416     ZNF10      CBX1
# 2    RANDCTRL - RANDCTRL       78  0.075772  1.292963  RANDCTRL  RANDCTRL
# 0           ANM2 - KIBRA       79  0.026166  0.669465      ANM2     KIBRA
# 2           BIN1 - FOXO3       80  1.252993  0.913119      BIN1     FOXO3
# 3           CACO1 - ANM2       81  0.016826  1.399375     CACO1      ANM2
# 5            CREM - MPP8       82  3.088495  0.950128      CREM      MPP8
# 235          DPF1 - HSF2       83  1.481086  0.922303      DPF1      HSF2
# 236        DPY30 - HXA13       84  0.538830  0.579243     DPY30     HXA13
# 237        MPP8 - ZNF791       87  3.403814  0.934646      MPP8    ZNF791
# 238         NOTC2 - ANM2       90  0.035155 -0.096756     NOTC2      ANM2
# 239        NOTC2 - KIBRA       91  0.771948  0.921027     NOTC2     KIBRA
# 340        SMCA2 - U2AF4       92  0.166648  0.449262     SMCA2     U2AF4
# 342         SUMO3 - SSX2       93  3.067263  0.926508     SUMO3      SSX2
# 343        YAF2 - ZNF791       94  3.973450  0.927227      YAF2    ZNF791
# 1           ATRX - HERC2       96  2.866741  0.939224      ATRX     HERC2
# 339        SCML2 - NOTC2       97  2.651466  0.967238     SCML2     NOTC2
# 4           CHD4 - CDYL2       98  4.004404  0.916355      CHD4     CDYL2
# 341         SMN2 - FOXO3       99  0.048303  0.089964      SMN2     FOXO3
#
#                                                   pair            type  \
# 0                                                  NaN             NaN
# 1    DMD_control_tiles;ENSG00000198947;;297; --- Ra...  2 control Pair
# 344  Human_KRAB_variant;P21506;146 --- Short_nuclea...  0 control Pair
# 345  Human_KRAB_variant;P21506;146 --- Short_nuclea...  0 control Pair
# 2      Random_control;;;205; --- Random_control;;;410;  2 control Pair
# 0    Short_nuclear_domain;ANM2_HUMAN;SH3_1;18;45 --...  0 control Pair
# 2    Short_nuclear_domain;BIN1_HUMAN;SH3_9;513;63 -...  0 control Pair
# 3    Short_nuclear_domain;CACO1_HUMAN;Zn-C2H2_12;61...  0 control Pair
# 5    Short_nuclear_domain;CREM_HUMAN;bZIP_1;265;45 ...  0 control Pair
# 235  Short_nuclear_domain;DPF1_HUMAN;Requiem_N;34;7...  0 control Pair
# 236  Short_nuclear_domain;DPY30_HUMAN;Dpy-30;19;41 ...  0 control Pair
# 237  Short_nuclear_domain;MPP8_HUMAN;Chromo;44;50 -...  0 control Pair
# 238  Short_nuclear_domain;NOTC2_HUMAN;Notch;1440;34...  0 control Pair
# 239  Short_nuclear_domain;NOTC2_HUMAN;Notch;1440;34...  0 control Pair
# 340  Short_nuclear_domain;SMCA2_HUMAN;QLQ;150;34 --...  0 control Pair
# 342  Short_nuclear_domain;SUMO3_HUMAN;Rad60-SLD;12;...  0 control Pair
# 343  Short_nuclear_domain;YAF2_HUMAN;YAF2_RYBP;78;3...  0 control Pair
# 1    Silencer_tiles;ENSG00000085224;242 --- Short_n...  0 control Pair
# 339  Silencer_tiles;ENSG00000102098;62 --- Short_nu...  0 control Pair
# 4    Silencer_tiles;ENSG00000111642;38 --- Short_nu...  0 control Pair
# 341  Silencer_tiles;ENSG00000205571;13 --- Short_nu...  0 control Pair
#
#      enrichment_ratio_r1_d2  enrichment_ratio_r1_d5  ...  rep_hit  \
# 0                       NaN                     NaN  ...      NaN
# 1                 -1.674298                1.845453  ...    False
# 344               -3.077474               -4.039409  ...     True
# 345               -2.280802                0.236960  ...     True
# 2                 -1.136912                1.514022  ...    False
# 0                  4.399647                1.963231  ...    False
# 2                  2.910184               -1.215860  ...     True
# 3                  4.293037                1.819199  ...    False
# 5                 -1.771883               -3.459034  ...     True
# 235               -6.270534                1.298109  ...    False
# 236                     NaN                     NaN  ...      NaN
# 237               -5.163618               -3.176634  ...     True
# 238                4.293155                1.939422  ...    False
# 239                1.132315               -1.144821  ...     True
# 340                3.262467                0.838505  ...    False
# 342               -2.600175               -3.377838  ...     True
# 343               -3.129806               -4.101878  ...     True
# 1                 -2.256287               -2.227251  ...     True
# 339               -1.609766               -1.261095  ...     True
# 4                 -2.505355               -3.874072  ...     True
# 341                4.688901                2.549140  ...    False
#
#      d1_prior_avg_d5  d1_prior_avg_dm  d1_prior_avg_d2  d2_prior_avg_d5  \
# 0                NaN              NaN              NaN              NaN
# 1          -0.481389        -0.300723         0.880544        -0.386730
# 344              NaN              NaN              NaN        -1.019050
# 345              NaN              NaN              NaN         6.952695
# 2          -0.213846        -0.499577         0.965604        -0.705059
# 0          -1.019050        -0.726941        -5.645672         0.243639
# 2           2.683747         1.246747         1.224325         1.492156
# 3           0.142909        -0.196617        -4.683274        -1.019050
# 5           4.587577         1.876879         2.598693         6.513346
# 235        -0.877510        -1.191838        -2.743392         4.314440
# 236        -0.750871        -0.694016        -3.696281         3.056264
# 237         6.513346         4.151363         5.335222              NaN
# 238         0.759808         0.077752        -5.258400        -1.019050
# 239         0.759808         0.077752        -5.258400         0.243639
# 340         1.088938         0.870292        -6.791645        -0.053175
# 342         6.764935         4.418768         2.783581         3.380894
# 343         6.257689         3.329343         1.811529              NaN
# 1                NaN              NaN              NaN         5.129901
# 339         4.346822         0.995849              NaN         0.759808
# 4           4.154102         1.279604              NaN         5.177775
# 341              NaN              NaN              NaN         1.492156
#
#      d2_prior_avg_dm  d2_prior_avg_d2  baseline_sum_d2  baseline_sum_d5  \
# 0                NaN              NaN              NaN              NaN
# 1          -0.391739         1.123830        -2.633567         1.421112
# 344        -0.726941        -5.645672        -2.992981        -1.179180
# 345         6.040754         6.560139        -5.076650        -5.456065
# 2          -0.498968         0.924894        -2.878058         0.765639
# 0           0.312334        -6.707792        -0.145996         3.174879
# 2           1.681687        -8.389172         1.352338         1.236541
# 3          -0.726941        -5.645672        -1.545303         3.142817
# 5           4.151363         5.335222        -4.841218        -2.697996
# 235         1.798662              NaN        -3.831008         0.835209
# 236         2.096968        -0.043040        -3.131331         2.734139
# 237              NaN              NaN        -5.252263        -4.962111
# 238        -0.726941        -5.645672        -0.914634         2.972803
# 239         0.312334        -6.707792        -0.210166         2.556613
# 340         0.131211        -3.355393        -1.729842         1.872948
# 342         3.499111         4.168672        -3.906820        -3.656192
# 343              NaN              NaN        -4.613514        -5.325869
# 1           1.486742         4.050937        -3.686474        -0.230680
# 339         0.077752        -5.258400        -2.497523         0.118596
# 4           4.974258         3.329373        -4.176443        -4.738963
# 341         1.681687        -8.389172         1.642877         2.434642
#
#       description_screen
# 0                    NaN
# 1         DMD - RANDCTRL
# 344                  NaN
# 345                  NaN
# 2    RANDCTRL - RANDCTRL
# 0                    NaN
# 2                    NaN
# 3                    NaN
# 5                    NaN
# 235                  NaN
# 236                  NaN
# 237                  NaN
# 238                  NaN
# 239                  NaN
# 340                  NaN
# 342                  NaN
# 343                  NaN
# 1                    NaN
# 339                  NaN
# 4                    NaN
# 341                  NaN
#
# [21 rows x 76 columns]

# %%
fig, ax = plt.subplots(figsize=(4, 4))

sns.scatterplot(
    data = zdf.dropna(subset=['character']),
    x = 'avg_enrichment_d5',
    y = 'ks',
    hue = 'character',
    palette = ['#dbc60d', '#23bedb', "#0fa616", "#dddddd"],
    ax=ax
)

ax.axvline(-1.713, color='k', linestyle='--')

ldf = zdf.dropna(subset=['character', 'avg_enrichment_d5', 'ks'])
#ldf = ldf[ldf['avg_enrichment_d5'] < -1.713]
m, b = np.polyfit(ldf['avg_enrichment_d5'], ldf['ks'], 1)
xvals = np.linspace(-6.5, 3.5)
yvals = [m*x + b for x in xvals]
ax.plot(xvals, yvals, color = "#DDDDDD", zorder=0)
r, p = st.pearsonr(ldf['avg_enrichment_d5'], ldf['ks'])
ax.text(-1.5, 3.8, "R$^2$ = {:.2f}".format(r**2))

# # fit line to actual data
# ldf = zdf.dropna(subset=['character'])
# ldf = ldf[ldf['avg_enrichment_d5'] <= -1.713]
# #m, b = np.polyfit(ldf['avg_enrichment_d5'], ldf['ks'], 1)
# r, p = st.pearsonr(ldf['avg_enrichment_d5'], ldf['ks'])
# ax.text(1.5, 0, "R$^2$ = {:.2f}".format(r**2))

# xvals = np.linspace(-6.5, 3.5)
# yvals = [m*x + b for x in xvals]
# #ax.plot(xvals, yvals, color='#DDDDDD', zorder=0)

ax.set_xlim(-6.5, 3.5)
ax.set_xticks([-6, -3, 0, 3])
ax.set_ylim(-0.2, 4.5)
ax.set_yticks([0, 2, 4])

ax.legend(title='', markerscale=1.0, bbox_to_anchor = (1.05, 1))

ax.set_xlabel('Repression Screen log$_2$(ON:OFF)')
ax.set_ylabel('Silencing Rate $k_s$')

#plt.tight_layout()

fig.savefig('./repressor_sil_correlation.pdf', bbox_inches = 'tight')
fig.savefig('./repressor_sil_correlation.png', dpi = 300)

# %% [markdown]
# # Correlating with Activation Data

# %%
act_data = pd.read_csv('../2021.11.15_activation_round1/activation_data.csv')
print(list(act_data.columns))
act_data
# Out:
# ['description', 'plasmid', 'day', 'dox', 'replicate', 'FSC 488/10-A', 'SSC 488/10-A', 'mCherry-A', 'mCitrine-A', 'P1', 'mCherry', 'Citrine On', 'domain1', 'domain2', 'pair', 'type', 'enrichment_ratio_r1_d2', 'enrichment_ratio_r1_d5', 'enrichment_ratio_r1_d10', 'enrichment_ratio_r2_d2', 'enrichment_ratio_r2_d5', 'enrichment_ratio_r2_d10', 'enrichment_fraction_r1_d2', 'enrichment_fraction_r1_d5', 'enrichment_fraction_r1_d10', 'enrichment_fraction_r2_d2', 'enrichment_fraction_r2_d5', 'enrichment_fraction_r2_d10', 'bound_r1_d2', 'bound_r1_d5', 'bound_r1_d10', 'bound_r2_d2', 'bound_r2_d5', 'bound_r2_d10', 'norm_bound_r1_d2', 'norm_bound_r1_d5', 'norm_bound_r1_d10', 'norm_bound_r2_d2', 'norm_bound_r2_d5', 'norm_bound_r2_d10', 'norm_unbound_r1_d2', 'norm_unbound_r1_d5', 'norm_unbound_r1_d10', 'norm_unbound_r2_d2', 'norm_unbound_r2_d5', 'norm_unbound_r2_d10', 'avg_enrichment_d2', 'avg_enrichment_d5', 'avg_enrichment_d10', 'domain1_screen', 'domain2_screen', 'd1_Gene', 'd1_Pathway', 'd1_Description', 'd2_Gene', 'd2_Pathway', 'd2_Description', 'd1_avg_d2', 'd1_med_d2', 'd1_sd_d2', 'd1_avg_d5', 'd1_med_d5', 'd1_sd_d5', 'd1_description', 'd2_avg_d2', 'd2_med_d2', 'd2_sd_d2', 'd2_avg_d5', 'd2_med_d5', 'd2_sd_d5', 'd2_description', 'composition', 'character', 'act_hit', 'rep_hit', 'd1_prior_avg_d5', 'd1_prior_avg_dm', 'd1_prior_avg_d2', 'd2_prior_avg_d5', 'd2_prior_avg_dm', 'd2_prior_avg_d2', 'baseline_sum_d2', 'baseline_sum_d5', 'description_screen']
#             description  plasmid  day     dox  replicate  FSC 488/10-A  \
# 0          ANM2 - KIBRA       79  2.0  1000.0        1.5  7.854868e+08
# 1          ATRX - HERC2       96  2.0  1000.0        1.5  7.822469e+08
# 2          BIN1 - FOXO3       80  2.0  1000.0        1.5  7.326128e+08
# 3          CACO1 - ANM2       81  2.0  1000.0        1.5  7.438811e+08
# 4          CHD4 - CDYL2       98  2.0  1000.0        1.5  7.578148e+08
# 5           CREM - MPP8       82  2.0  1000.0        1.5  7.519720e+08
# 6           DPF1 - HSF2       83  2.0  1000.0        1.5  7.358323e+08
# 7         DPY30 - HXA13       84  2.0  1000.0        1.5  7.306644e+08
# 8         MPP8 - ZNF791       87  2.0  1000.0        1.5  7.667548e+08
# 9          NOTC2 - ANM2       90  2.0  1000.0        1.5  7.524635e+08
# 10        NOTC2 - KIBRA       91  2.0  1000.0        1.5  7.311497e+08
# 11        SCML2 - NOTC2       97  2.0  1000.0        1.5  7.571613e+08
# 12        SMCA2 - U2AF4       92  2.0  1000.0        1.5  8.131067e+08
# 13         SMN2 - FOXO3       99  2.0  1000.0        1.5  7.299302e+08
# 14         SUMO3 - SSX2       93  2.0  1000.0        1.5  7.527660e+08
# 15        YAF2 - ZNF791       94  2.0  1000.0        1.5  7.680592e+08
# 16         ZNF10 - ANM2       76  2.0  1000.0        1.5  7.640966e+08
# 17         ZNF10 - CBX1       77  2.0  1000.0        1.5  7.646349e+08
# 18            DMD - DMD       74  2.0  1000.0        1.5  7.829764e+08
# 19       DMD - RANDCTRL       75  2.0  1000.0        1.5  7.570796e+08
# 20  RANDCTRL - RANDCTRL       78  2.0  1000.0        1.5  7.715687e+08
#
#     SSC 488/10-A     mCherry-A    mCitrine-A   P1  ...  rep_hit  \
# 0   2.173589e+08  2.280779e+08  2.585994e+08  1.0  ...    False
# 1   2.094257e+08  2.252698e+08  1.972691e+06  1.0  ...     True
# 2   2.039081e+08  1.425160e+08  5.691427e+07  1.0  ...     True
# 3   2.054264e+08  1.788837e+08  2.661532e+08  1.0  ...    False
# 4   2.072625e+08  1.819361e+08  1.896662e+06  1.0  ...     True
# 5   2.048163e+08  1.990641e+08  1.885947e+06  1.0  ...     True
# 6   2.059303e+08  1.582734e+08  1.979073e+06  1.0  ...    False
# 7   2.029543e+08  1.412203e+08  1.965050e+06  1.0  ...      NaN
# 8   2.105313e+08  2.291278e+08  1.888433e+06  1.0  ...     True
# 9   2.084351e+08  1.673833e+08  3.013375e+08  1.0  ...    False
# 10  1.982717e+08  1.688556e+08  2.269993e+07  1.0  ...     True
# 11  2.076169e+08  1.880977e+08  1.837992e+06  1.0  ...     True
# 12  2.203500e+08  3.323890e+08  7.521359e+07  1.0  ...    False
# 13  1.970772e+08  1.763397e+08  1.559750e+08  1.0  ...    False
# 14  2.115023e+08  1.718641e+08  1.884992e+06  1.0  ...     True
# 15  2.079913e+08  2.562761e+08  1.823387e+06  1.0  ...     True
# 16  2.081958e+08  1.800109e+08  1.938275e+06  1.0  ...     True
# 17  2.062167e+08  2.343948e+08  1.999022e+06  1.0  ...     True
# 18  2.127943e+08  2.739791e+08  1.879664e+06  1.0  ...      NaN
# 19  2.041667e+08  2.615916e+08  1.937615e+06  1.0  ...    False
# 20  2.060212e+08  1.889495e+08  2.038273e+06  1.0  ...    False
#
#     d1_prior_avg_d5 d1_prior_avg_dm d1_prior_avg_d2 d2_prior_avg_d5  \
# 0         -1.019050       -0.726941       -5.645672        0.243639
# 1               NaN             NaN             NaN        5.129901
# 2          2.683747        1.246747        1.224325        1.492156
# 3          0.142909       -0.196617       -4.683274       -1.019050
# 4          4.154102        1.279604             NaN        5.177775
# 5          4.587577        1.876879        2.598693        6.513346
# 6         -0.877510       -1.191838       -2.743392        4.314440
# 7         -0.750871       -0.694016       -3.696281        3.056264
# 8          6.513346        4.151363        5.335222             NaN
# 9          0.759808        0.077752       -5.258400       -1.019050
# 10         0.759808        0.077752       -5.258400        0.243639
# 11         4.346822        0.995849             NaN        0.759808
# 12         1.088938        0.870292       -6.791645       -0.053175
# 13              NaN             NaN             NaN        1.492156
# 14         6.764935        4.418768        2.783581        3.380894
# 15         6.257689        3.329343        1.811529             NaN
# 16              NaN             NaN             NaN       -1.019050
# 17              NaN             NaN             NaN        6.952695
# 18              NaN             NaN             NaN             NaN
# 19        -0.481389       -0.300723        0.880544       -0.386730
# 20        -0.213846       -0.499577        0.965604       -0.705059
#
#    d2_prior_avg_dm  d2_prior_avg_d2  baseline_sum_d2  baseline_sum_d5  \
# 0         0.312334        -6.707792        -0.145996         3.174879
# 1         1.486742         4.050937        -3.686474        -0.230680
# 2         1.681687        -8.389172         1.352338         1.236541
# 3        -0.726941        -5.645672        -1.545303         3.142817
# 4         4.974258         3.329373        -4.176443        -4.738963
# 5         4.151363         5.335222        -4.841218        -2.697996
# 6         1.798662              NaN        -3.831008         0.835209
# 7         2.096968        -0.043040        -3.131331         2.734139
# 8              NaN              NaN        -5.252263        -4.962111
# 9        -0.726941        -5.645672        -0.914634         2.972803
# 10        0.312334        -6.707792        -0.210166         2.556613
# 11        0.077752        -5.258400        -2.497523         0.118596
# 12        0.131211        -3.355393        -1.729842         1.872948
# 13        1.681687        -8.389172         1.642877         2.434642
# 14        3.499111         4.168672        -3.906820        -3.656192
# 15             NaN              NaN        -4.613514        -5.325869
# 16       -0.726941        -5.645672        -2.992981        -1.179180
# 17        6.040754         6.560139        -5.076650        -5.456065
# 18             NaN              NaN              NaN              NaN
# 19       -0.391739         1.123830        -2.633567         1.421112
# 20       -0.498968         0.924894        -2.878058         0.765639
#
#      description_screen
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11                  NaN
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# 17                  NaN
# 18                  NaN
# 19       DMD - RANDCTRL
# 20  RANDCTRL - RANDCTRL
#
# [21 rows x 84 columns]

# %%
vdf = zdf.set_index('description').join(
    act_data.set_index('description'),
    on = 'description',
    how = 'left',
    rsuffix = '_act'
).reset_index()
vdf = vdf[['description', 'plasmid', 'ks', 'tlag', 'Citrine On', 'character']]
vdf['character'] = list(vdf['character'])[0:18] + ['Control'] + list(vdf['character'])[19:]
vdf
# Out:
#             description  plasmid        ks      tlag  Citrine On  character
# 0          ANM2 - KIBRA       79  0.026166  0.669465    0.962426  Activator
# 1          ATRX - HERC2       96  2.866741  0.939224    0.011904  Repressor
# 2          BIN1 - FOXO3       80  1.252993  0.913119    0.691774       Both
# 3          CACO1 - ANM2       81  0.016826  1.399375    0.948644  Activator
# 4          CHD4 - CDYL2       98  4.004404  0.916355    0.009700  Repressor
# 5           CREM - MPP8       82  3.088495  0.950128    0.009251  Repressor
# 6           DPF1 - HSF2       83  1.481086  0.922303    0.028202       Both
# 7         DPY30 - HXA13       84  0.538830  0.579243    0.017484       Both
# 8         MPP8 - ZNF791       87  3.403814  0.934646    0.010100  Repressor
# 9          NOTC2 - ANM2       90  0.035155 -0.096756    0.939169  Activator
# 10        NOTC2 - KIBRA       91  0.771948  0.921027    0.295826  Activator
# 11        SCML2 - NOTC2       97  2.651466  0.967238    0.006138       Both
# 12        SMCA2 - U2AF4       92  0.166648  0.449262    0.763336  Activator
# 13         SMN2 - FOXO3       99  0.048303  0.089964    0.922178       Both
# 14         SUMO3 - SSX2       93  3.067263  0.926508    0.008472  Repressor
# 15        YAF2 - ZNF791       94  3.973450  0.927227    0.006067  Repressor
# 16         ZNF10 - ANM2       76  3.178141  0.938369    0.007662       Both
# 17         ZNF10 - CBX1       77  2.958838  0.926416    0.021846  Repressor
# 18            DMD - DMD       74  0.015397  0.534274    0.011909    Control
# 19       DMD - RANDCTRL       75  0.025531  1.804237    0.011352    Control
# 20  RANDCTRL - RANDCTRL       78  0.075772  1.292963    0.017472    Control

# %%
char_text_map = {
    'Activator' : 'C-A, A-C, A-A',
    'Repressor' : 'C-R, R-C, R-R',
    'Both'      : 'A-R, R-A',
    'Control'   : 'C-C'
}

vdf['character_map'] = [char_text_map[c] for c in list(vdf['character'])]
vdf
# Out:
#             description  plasmid        ks      tlag  Citrine On  character  \
# 0          ANM2 - KIBRA       79  0.026166  0.669465    0.962426  Activator
# 1          ATRX - HERC2       96  2.866741  0.939224    0.011904  Repressor
# 2          BIN1 - FOXO3       80  1.252993  0.913119    0.691774       Both
# 3          CACO1 - ANM2       81  0.016826  1.399375    0.948644  Activator
# 4          CHD4 - CDYL2       98  4.004404  0.916355    0.009700  Repressor
# 5           CREM - MPP8       82  3.088495  0.950128    0.009251  Repressor
# 6           DPF1 - HSF2       83  1.481086  0.922303    0.028202       Both
# 7         DPY30 - HXA13       84  0.538830  0.579243    0.017484       Both
# 8         MPP8 - ZNF791       87  3.403814  0.934646    0.010100  Repressor
# 9          NOTC2 - ANM2       90  0.035155 -0.096756    0.939169  Activator
# 10        NOTC2 - KIBRA       91  0.771948  0.921027    0.295826  Activator
# 11        SCML2 - NOTC2       97  2.651466  0.967238    0.006138       Both
# 12        SMCA2 - U2AF4       92  0.166648  0.449262    0.763336  Activator
# 13         SMN2 - FOXO3       99  0.048303  0.089964    0.922178       Both
# 14         SUMO3 - SSX2       93  3.067263  0.926508    0.008472  Repressor
# 15        YAF2 - ZNF791       94  3.973450  0.927227    0.006067  Repressor
# 16         ZNF10 - ANM2       76  3.178141  0.938369    0.007662       Both
# 17         ZNF10 - CBX1       77  2.958838  0.926416    0.021846  Repressor
# 18            DMD - DMD       74  0.015397  0.534274    0.011909    Control
# 19       DMD - RANDCTRL       75  0.025531  1.804237    0.011352    Control
# 20  RANDCTRL - RANDCTRL       78  0.075772  1.292963    0.017472    Control
#
#     character_map
# 0   C-A, A-C, A-A
# 1   C-R, R-C, R-R
# 2        A-R, R-A
# 3   C-A, A-C, A-A
# 4   C-R, R-C, R-R
# 5   C-R, R-C, R-R
# 6        A-R, R-A
# 7        A-R, R-A
# 8   C-R, R-C, R-R
# 9   C-A, A-C, A-A
# 10  C-A, A-C, A-A
# 11       A-R, R-A
# 12  C-A, A-C, A-A
# 13       A-R, R-A
# 14  C-R, R-C, R-R
# 15  C-R, R-C, R-R
# 16       A-R, R-A
# 17  C-R, R-C, R-R
# 18            C-C
# 19            C-C
# 20            C-C

# %%
fig, ax = plt.subplots(figsize=(4,4))

sns.scatterplot(
    data = vdf,
    x = 'Citrine On',
    y = 'ks',
    hue = 'character_map',
    palette = ['#dbc60d', '#23bedb', "#0fa616", "#dddddd"],
    ax = ax
)

ax.legend(title='', markerscale=1.0)#, bbox_to_anchor = (1.7, 1.1))
ax.set_xlim(-0.05, 1.05)
ax.set_ylim(-0.2, 4.5)

ax.set_xlabel('Day 2 Fraction On')
ax.set_ylabel('Silencing Rate $k_s$')

plt.tight_layout()
fig.savefig('./activation_ks_correlation.pdf', bbox_inches = 'tight')

# %% [markdown]
# # Some Distributions

# %%
bfdf = df[df['description'].str.contains('BIN1')]
bfdf

sns.kdeplot(
    data = bfdf[bfdf['dox']==1000],
    x = 'mCitrine-A',
    hue = 'day',
    palette = 'PiYG',
    log_scale = True,
    common_norm = False
)
# Out:
# <AxesSubplot:xlabel='mCitrine-A', ylabel='Density'>
